# %% [markdown]
# # Análise de Dados - Prouni 2016
#
# Conjunto de dados que apresenta as bolsas concedidas e o perfil dos beneficiários do ProUni de 2016.
#
# Os dados são disponibilizados pelo Site Dados Abertos (http://dadosabertos.mec.gov.br/prouni), em arquivo CSV.

# %%
import pandas as pd

df = pd.read_csv('datasets/pda-prouni-2016.csv', sep = ';', encoding = 'ISO-8859-1')

# %% [markdown]
# ## Conhecendo o dataframe

# %%
df.sample(5)
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 114345                 2016                    374
# 164300                 2016                   1772
# 92336                  2016                    322
# 22342                  2016                   1196
# 54698                  2016                    203
#
#                                            NOME_IES_BOLSA         TIPO_BOLSA  \
# 114345  CENTRO UNIVERSITÁRIO DAS FACULDADES METROPOLIT...     BOLSA INTEGRAL
# 164300                                 FACULDADE NORDESTE  BOLSA PARCIAL 50%
# 92336                               UNIVERSIDADE PAULISTA     BOLSA INTEGRAL
# 22342        CENTRO UNIVERSITÁRIO DE MARINGÁ - UNICESUMAR     BOLSA INTEGRAL
# 54698                        UNIVERSIDADE SÃO JUDAS TADEU  BOLSA PARCIAL 50%
#
#        MODALIDADE_ENSINO_BOLSA                    NOME_CURSO_BOLSA  \
# 114345              PRESENCIAL                    Engenharia Civil
# 164300              PRESENCIAL                          Jornalismo
# 92336               PRESENCIAL                             Direito
# 22342     EDUCAÇÃO A DISTÂNCIA                   Gestão Hospitalar
# 54698               PRESENCIAL  Engenharia De Controle E Automação
#
#        NOME_TURNO_CURSO_BOLSA CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA  \
# 114345               Matutino            ***730856**                Feminino
# 164300                Noturno            ***694223**                Feminino
# 92336                Matutino            ***627018**               Masculino
# 22342       Curso a distância            ***896309**                Feminino
# 54698                 Noturno            ***650858**               Masculino
#
#        RACA_BENEFICIARIO_BOLSA DT_NASCIMENTO_BENEFICIARIO  \
# 114345                  Branca                 22-08-1993
# 164300                   Preta                 21-08-1995
# 92336                    Parda                 29-09-1996
# 22342                   Branca                 12-12-1994
# 54698                   Branca                 25-05-1992
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO_BOLSA  \
# 114345                            NÃO                   SUDESTE
# 164300                            NÃO                  NORDESTE
# 92336                             NÃO                   SUDESTE
# 22342                             NÃO                       SUL
# 54698                             NÃO                   SUDESTE
#
#        SIGLA_UF_BENEFICIARIO_BOLSA MUNICIPIO_BENEFICIARIO_BOLSA
# 114345                          SP                    SÃO PAULO
# 164300                          CE                      EUSÉBIO
# 92336                           SP                    SÃO PAULO
# 22342                           SC                     BLUMENAU
# 54698                           SP                    SÃO PAULO

# %%
df.shape
# Out:
# (239262, 15)

# %%
df.dtypes
# Out:
# ANO_CONCESSAO_BOLSA                int64
# CODIGO_EMEC_IES_BOLSA              int64
# NOME_IES_BOLSA                    object
# TIPO_BOLSA                        object
# MODALIDADE_ENSINO_BOLSA           object
# NOME_CURSO_BOLSA                  object
# NOME_TURNO_CURSO_BOLSA            object
# CPF_BENEFICIARIO_BOLSA            object
# SEXO_BENEFICIARIO_BOLSA           object
# RACA_BENEFICIARIO_BOLSA           object
# DT_NASCIMENTO_BENEFICIARIO        object
# BENEFICIARIO_DEFICIENTE_FISICO    object
# REGIAO_BENEFICIARIO_BOLSA         object
# SIGLA_UF_BENEFICIARIO_BOLSA       object
# MUNICIPIO_BENEFICIARIO_BOLSA      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ANO_CONCESSAO_BOLSA                0
# CODIGO_EMEC_IES_BOLSA              0
# NOME_IES_BOLSA                     0
# TIPO_BOLSA                         0
# MODALIDADE_ENSINO_BOLSA            0
# NOME_CURSO_BOLSA                  44
# NOME_TURNO_CURSO_BOLSA             0
# CPF_BENEFICIARIO_BOLSA             0
# SEXO_BENEFICIARIO_BOLSA            0
# RACA_BENEFICIARIO_BOLSA            0
# DT_NASCIMENTO_BENEFICIARIO         0
# BENEFICIARIO_DEFICIENTE_FISICO     0
# REGIAO_BENEFICIARIO_BOLSA          0
# SIGLA_UF_BENEFICIARIO_BOLSA        0
# MUNICIPIO_BENEFICIARIO_BOLSA       0
# dtype: int64

# %% [markdown]
# ## Dados nulos
#
# - A Coluna NOME_CURSO_BOLSA, consta a falta de 44 registros;
#
# ### Atribuindo valores na Coluna NOME_CURSO_BOLSA
#
# -> Todos os elementos vazios serão preenchidos com o valor definido 'Não Registrado'

# %%
df[df['NOME_CURSO_BOLSA'].isnull()]
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 1957                   2016                    163
# 3012                   2016                    163
# 9735                   2016                    271
# 10406                  2016                    823
# 30185                  2016                   5591
# 47999                  2016                    143
# 55770                  2016                    337
# 55771                  2016                    337
# 55772                  2016                    337
# 58099                  2016                    384
# 63201                  2016                   1087
# 64891                  2016                    823
# 65548                  2016                    792
# 68789                  2016                   1410
# 79988                  2016                   2174
# 81133                  2016                   3840
# 92198                  2016                    823
# 101907                 2016                     21
# 131823                 2016                     83
# 135382                 2016                    437
# 143184                 2016                    466
# 144289                 2016                    466
# 153290                 2016                    322
# 165059                 2016                    792
# 166148                 2016                  11544
# 168769                 2016                     11
# 170776                 2016                     10
# 174124                 2016                     14
# 176706                 2016                    143
# 177690                 2016                    337
# 177865                 2016                    337
# 183504                 2016                    496
# 189485                 2016                    792
# 189486                 2016                    792
# 195895                 2016                   1777
# 199364                 2016                   3840
# 202517                 2016                   2896
# 204998                 2016                   3840
# 209986                 2016                   4197
# 212038                 2016                    338
# 216768                 2016                     21
# 218328                 2016                     20
# 222684                 2016                   4163
# 225829                 2016                   5544
#
#                                            NOME_IES_BOLSA         TIPO_BOLSA  \
# 1957                           UNIVERSIDADE ESTÁCIO DE SÁ     BOLSA INTEGRAL
# 3012                           UNIVERSIDADE ESTÁCIO DE SÁ     BOLSA INTEGRAL
# 9735                       UNIVERSIDADE DO OESTE PAULISTA     BOLSA INTEGRAL
# 10406                    UNIVERSIDADE DO CEUMA - UNICEUMA  BOLSA PARCIAL 50%
# 30185                        FACULDADES INTEGRADAS CAMÕES     BOLSA INTEGRAL
# 47999                             UNIVERSIDADE DE UBERABA     BOLSA INTEGRAL
# 55770           CENTRO DE ENSINO SUPERIOR DE JUIZ DE FORA     BOLSA INTEGRAL
# 55771           CENTRO DE ENSINO SUPERIOR DE JUIZ DE FORA     BOLSA INTEGRAL
# 55772           CENTRO DE ENSINO SUPERIOR DE JUIZ DE FORA  BOLSA PARCIAL 50%
# 58099                    CENTRO UNIVERSITÁRIO DE ANÁPOLIS     BOLSA INTEGRAL
# 63201             FACULDADES INTEGRADAS APARÍCIO CARVALHO     BOLSA INTEGRAL
# 64891                    UNIVERSIDADE DO CEUMA - UNICEUMA     BOLSA INTEGRAL
# 65548              CENTRO UNIVERSITÁRIO DO ESTADO DO PARÁ     BOLSA INTEGRAL
# 68789           ÁREA1 - FACULDADE DE CIÊNCIA E TECNOLOGIA  BOLSA PARCIAL 50%
# 79988                         FACULDADE DE SANTA CATARINA     BOLSA INTEGRAL
# 81133                       CENTRO UNIVERSITÁRIO FACVEST      BOLSA INTEGRAL
# 92198                    UNIVERSIDADE DO CEUMA - UNICEUMA  BOLSA PARCIAL 50%
# 101907  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO RIO GRANDE...     BOLSA INTEGRAL
# 131823                     UNIVERSIDADE DO VALE DO ITAJAÍ     BOLSA INTEGRAL
# 135382                            UNIVERSIDADE PARANAENSE     BOLSA INTEGRAL
# 143184                       UNIVERSIDADE ANHEMBI MORUMBI     BOLSA INTEGRAL
# 144289                       UNIVERSIDADE ANHEMBI MORUMBI     BOLSA INTEGRAL
# 153290                              UNIVERSIDADE PAULISTA     BOLSA INTEGRAL
# 165059             CENTRO UNIVERSITÁRIO DO ESTADO DO PARÁ     BOLSA INTEGRAL
# 166148                FACULDADE METROPOLITANA DE ANÁPOLIS     BOLSA INTEGRAL
# 168769                UNIVERSIDADE CATÓLICA DE PERNAMBUCO     BOLSA INTEGRAL
# 170776         PONTIFÍCIA UNIVERSIDADE CATÓLICA DO PARANÁ     BOLSA INTEGRAL
# 174124              UNIVERSIDADE DO VALE DO RIO DOS SINOS     BOLSA INTEGRAL
# 176706                            UNIVERSIDADE DE UBERABA     BOLSA INTEGRAL
# 177690          CENTRO DE ENSINO SUPERIOR DE JUIZ DE FORA     BOLSA INTEGRAL
# 177865          CENTRO DE ENSINO SUPERIOR DE JUIZ DE FORA  BOLSA PARCIAL 50%
# 183504                             UNIVERSIDADE DE FRANCA     BOLSA INTEGRAL
# 189485             CENTRO UNIVERSITÁRIO DO ESTADO DO PARÁ     BOLSA INTEGRAL
# 189486             CENTRO UNIVERSITÁRIO DO ESTADO DO PARÁ     BOLSA INTEGRAL
# 195895              FACULDADE METROPOLITANA DE GUARAMIRIM     BOLSA INTEGRAL
# 199364                      CENTRO UNIVERSITÁRIO FACVEST      BOLSA INTEGRAL
# 202517                                     FACULDADE SATC     BOLSA INTEGRAL
# 204998                      CENTRO UNIVERSITÁRIO FACVEST      BOLSA INTEGRAL
# 209986                                  FACULDADE ALIANÇA     BOLSA INTEGRAL
# 212038   PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS     BOLSA INTEGRAL
# 216768  PONTIFÍCIA UNIVERSIDADE CATÓLICA DO RIO GRANDE...     BOLSA INTEGRAL
# 218328                        UNIVERSIDADE DE PASSO FUNDO     BOLSA INTEGRAL
# 222684                 CENTRO UNIVERSITÁRIO BARRIGA VERDE     BOLSA INTEGRAL
# 225829                FACULDADE PRESIDENTE ANTÔNIO CARLOS     BOLSA INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 1957                PRESENCIAL              NaN               Matutino
# 3012                PRESENCIAL              NaN                Noturno
# 9735                PRESENCIAL              NaN               Integral
# 10406               PRESENCIAL              NaN                Noturno
# 30185               PRESENCIAL              NaN                Noturno
# 47999               PRESENCIAL              NaN               Integral
# 55770               PRESENCIAL              NaN               Matutino
# 55771               PRESENCIAL              NaN               Matutino
# 55772               PRESENCIAL              NaN               Matutino
# 58099               PRESENCIAL              NaN                Noturno
# 63201               PRESENCIAL              NaN                Noturno
# 64891               PRESENCIAL              NaN               Integral
# 65548               PRESENCIAL              NaN               Integral
# 68789               PRESENCIAL              NaN                Noturno
# 79988               PRESENCIAL              NaN                Noturno
# 81133               PRESENCIAL              NaN               Matutino
# 92198               PRESENCIAL              NaN                Noturno
# 101907              PRESENCIAL              NaN               Integral
# 131823              PRESENCIAL              NaN                Noturno
# 135382              PRESENCIAL              NaN                Noturno
# 143184              PRESENCIAL              NaN             Vespertino
# 144289              PRESENCIAL              NaN                Noturno
# 153290              PRESENCIAL              NaN                Noturno
# 165059              PRESENCIAL              NaN               Matutino
# 166148              PRESENCIAL              NaN                Noturno
# 168769              PRESENCIAL              NaN               Matutino
# 170776              PRESENCIAL              NaN               Integral
# 174124              PRESENCIAL              NaN                Noturno
# 176706              PRESENCIAL              NaN               Integral
# 177690              PRESENCIAL              NaN               Matutino
# 177865              PRESENCIAL              NaN               Matutino
# 183504              PRESENCIAL              NaN               Matutino
# 189485              PRESENCIAL              NaN               Integral
# 189486              PRESENCIAL              NaN               Integral
# 195895              PRESENCIAL              NaN                Noturno
# 199364              PRESENCIAL              NaN                Noturno
# 202517              PRESENCIAL              NaN                Noturno
# 204998              PRESENCIAL              NaN                Noturno
# 209986              PRESENCIAL              NaN               Matutino
# 212038              PRESENCIAL              NaN             Vespertino
# 216768              PRESENCIAL              NaN                Noturno
# 218328              PRESENCIAL              NaN                Noturno
# 222684              PRESENCIAL              NaN               Integral
# 225829              PRESENCIAL              NaN               Integral
#
#        CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA RACA_BENEFICIARIO_BOLSA  \
# 1957              ***535757**               Masculino                   Parda
# 3012              ***532347**               Masculino                   Parda
# 9735              ***498058**               Masculino           Não Informada
# 10406             ***726693**                Feminino                  Branca
# 30185             ***696659**                Feminino                   Parda
# 47999             ***312006**               Masculino                  Branca
# 55770             ***791076**                Feminino                   Parda
# 55771             ***789886**                Feminino                   Parda
# 55772             ***737096**                Feminino                  Branca
# 58099             ***900661**                Feminino                  Branca
# 63201             ***640942**               Masculino                  Branca
# 64891             ***011513**               Masculino                  Branca
# 65548             ***983012**               Masculino           Não Informada
# 68789             ***280265**                Feminino                 Amarela
# 79988             ***712589**                Feminino                  Branca
# 81133             ***205379**                Feminino                  Branca
# 92198             ***597763**               Masculino                 Amarela
# 101907            ***486630**               Masculino                  Branca
# 131823            ***400700**               Masculino                  Branca
# 135382            ***799442**                Feminino                   Parda
# 143184            ***622948**               Masculino                  Branca
# 144289            ***763128**                Feminino                   Parda
# 153290            ***857718**                Feminino                  Branca
# 165059            ***287642**                Feminino                   Parda
# 166148            ***115911**                Feminino                   Preta
# 168769            ***517754**                Feminino                 Amarela
# 170776            ***084828**                Feminino                 Amarela
# 174124            ***223830**               Masculino                  Branca
# 176706            ***271896**               Masculino                   Parda
# 177690            ***109556**               Masculino                   Parda
# 177865            ***020826**                Feminino                   Parda
# 183504            ***276898**               Masculino                  Branca
# 189485            ***931822**                Feminino           Não Informada
# 189486            ***931182**                Feminino           Não Informada
# 195895            ***343751**               Masculino                  Branca
# 199364            ***331500**               Masculino                  Branca
# 202517            ***708970**                Feminino                  Branca
# 204998            ***652060**                Feminino                  Branca
# 209986            ***758843**               Masculino                   Preta
# 212038            ***179636**                Feminino                  Branca
# 216768            ***771190**               Masculino                  Branca
# 218328            ***674380**                Feminino                 Amarela
# 222684            ***635650**               Masculino                  Branca
# 225829            ***555662**               Masculino                   Parda
#
#        DT_NASCIMENTO_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  \
# 1957                   13-03-1998                            NÃO
# 3012                   16-03-1974                            NÃO
# 9735                   04-05-1998                            NÃO
# 10406                  21-08-1997                            NÃO
# 30185                  15-04-1997                            NÃO
# 47999                  23-06-1992                            NÃO
# 55770                  26-10-1998                            NÃO
# 55771                  15-03-1997                            NÃO
# 55772                  07-07-1997                            NÃO
# 58099                  10-02-1967                            NÃO
# 63201                  26-02-1991                            NÃO
# 64891                  11-01-1996                            NÃO
# 65548                  17-05-2000                            NÃO
# 68789                  29-12-1993                            NÃO
# 79988                  28-09-1998                            NÃO
# 81133                  25-10-1998                            NÃO
# 92198                  13-11-1991                            NÃO
# 101907                 12-01-1998                            NÃO
# 131823                 21-09-1998                            NÃO
# 135382                 28-02-1997                            NÃO
# 143184                 20-11-1998                            NÃO
# 144289                 12-01-1997                            NÃO
# 153290                 06-11-1998                            NÃO
# 165059                 13-03-1996                            NÃO
# 166148                 19-03-1994                            NÃO
# 168769                 08-08-1995                            NÃO
# 170776                 10-09-1995                            NÃO
# 174124                 21-05-1991                            NÃO
# 176706                 14-09-1991                            NÃO
# 177690                 09-04-1996                            NÃO
# 177865                 08-04-1998                            NÃO
# 183504                 30-03-1996                            NÃO
# 189485                 19-04-1992                            NÃO
# 189486                 19-04-1992                            NÃO
# 195895                 19-06-1989                            NÃO
# 199364                 25-06-1997                            NÃO
# 202517                 25-06-1998                            NÃO
# 204998                 15-10-1994                            NÃO
# 209986                 10-06-1999                            NÃO
# 212038                 31-01-1994                            NÃO
# 216768                 25-02-1978                            NÃO
# 218328                 02-03-1997                            NÃO
# 222684                 23-01-1998                            NÃO
# 225829                 21-07-1998                            NÃO
#
#        REGIAO_BENEFICIARIO_BOLSA SIGLA_UF_BENEFICIARIO_BOLSA  \
# 1957                     SUDESTE                          RJ
# 3012                     SUDESTE                          RJ
# 9735                     SUDESTE                          SP
# 10406                   NORDESTE                          MA
# 30185                        SUL                          PR
# 47999                    SUDESTE                          MG
# 55770                    SUDESTE                          MG
# 55771                    SUDESTE                          MG
# 55772                    SUDESTE                          MG
# 58099               CENTRO-OESTE                          GO
# 63201                      NORTE                          RO
# 64891                   NORDESTE                          MA
# 65548                      NORTE                          PA
# 68789                   NORDESTE                          BA
# 79988                        SUL                          SC
# 81133                        SUL                          SC
# 92198                   NORDESTE                          MA
# 101907                       SUL                          RS
# 131823                       SUL                          RS
# 135382                       SUL                          PR
# 143184                   SUDESTE                          SP
# 144289                   SUDESTE                          SP
# 153290                   SUDESTE                          SP
# 165059                     NORTE                          PA
# 166148              CENTRO-OESTE                          DF
# 168769                  NORDESTE                          PE
# 170776                   SUDESTE                          SP
# 174124                       SUL                          RS
# 176706                   SUDESTE                          MG
# 177690                   SUDESTE                          MG
# 177865                   SUDESTE                          MG
# 183504                   SUDESTE                          SP
# 189485                     NORTE                          PA
# 189486                     NORTE                          PA
# 195895                       SUL                          SC
# 199364                       SUL                          RS
# 202517                       SUL                          RS
# 204998                       SUL                          RS
# 209986                  NORDESTE                          MA
# 212038                   SUDESTE                          MG
# 216768                       SUL                          RS
# 218328                       SUL                          RS
# 222684                       SUL                          RS
# 225829                     NORTE                          PA
#
#        MUNICIPIO_BENEFICIARIO_BOLSA
# 1957          CAMPOS DOS GOYTACAZES
# 3012                 RIO DE JANEIRO
# 9735            PRESIDENTE PRUDENTE
# 10406                      SÃO LUÍS
# 30185                      CURITIBA
# 47999                       UBERABA
# 55770                  JUIZ DE FORA
# 55771                  JUIZ DE FORA
# 55772                  JUIZ DE FORA
# 58099                      ANÁPOLIS
# 63201                   PORTO VELHO
# 64891                      SÃO LUÍS
# 65548                         BELÉM
# 68789                      SALVADOR
# 79988                      SÃO JOSÉ
# 81133                         LAGES
# 92198                      SÃO LUÍS
# 101907                 PORTO ALEGRE
# 131823                         IJUÍ
# 135382                       ABATIÁ
# 143184                   ADAMANTINA
# 144289                       OSASCO
# 153290                     PALMITAL
# 165059                     MARITUBA
# 166148                     BRASÍLIA
# 168769                     IGARASSU
# 170776          SÃO JOSÉ DOS CAMPOS
# 174124              FLORES DA CUNHA
# 176706                MONTE CARMELO
# 177690                SANTOS DUMONT
# 177865               MATIAS BARBOSA
# 183504                     BATATAIS
# 189485                   ANANINDEUA
# 189486                   ABAETETUBA
# 195895               JARAGUÁ DO SUL
# 199364                     BARRACÃO
# 202517                       TORRES
# 204998                       ACEGUÁ
# 209986                        TIMON
# 212038                     CONTAGEM
# 216768                     ALVORADA
# 218328          SÃO DOMINGOS DO SUL
# 222684           JÚLIO DE CASTILHOS
# 225829                     REDENÇÃO

# %%
df.update(df['NOME_CURSO_BOLSA'].fillna('Não Registrado'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 239262 entries, 0 to 239261
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ANO_CONCESSAO_BOLSA             239262 non-null  int64
#  1   CODIGO_EMEC_IES_BOLSA           239262 non-null  int64
#  2   NOME_IES_BOLSA                  239262 non-null  object
#  3   TIPO_BOLSA                      239262 non-null  object
#  4   MODALIDADE_ENSINO_BOLSA         239262 non-null  object
#  5   NOME_CURSO_BOLSA                239262 non-null  object
#  6   NOME_TURNO_CURSO_BOLSA          239262 non-null  object
#  7   CPF_BENEFICIARIO_BOLSA          239262 non-null  object
#  8   SEXO_BENEFICIARIO_BOLSA         239262 non-null  object
#  9   RACA_BENEFICIARIO_BOLSA         239262 non-null  object
#  10  DT_NASCIMENTO_BENEFICIARIO      239262 non-null  object
#  11  BENEFICIARIO_DEFICIENTE_FISICO  239262 non-null  object
#  12  REGIAO_BENEFICIARIO_BOLSA       239262 non-null  object
#  13  SIGLA_UF_BENEFICIARIO_BOLSA     239262 non-null  object
#  14  MUNICIPIO_BENEFICIARIO_BOLSA    239262 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 27.4+ MB

# %% [markdown]
# ### Excluindo as Colunas CPF_BENEFICIARIO_BOLSA e MUNICIPIO_BENEFICIARIO_BOLSA

# %%
df.drop(['CPF_BENEFICIARIO_BOLSA','MUNICIPIO_BENEFICIARIO_BOLSA'] , axis=1, inplace = True)

# %% [markdown]
# ### Renomeando Colunas

# %%
df.columns
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'SEXO_BENEFICIARIO_BOLSA',
#        'RACA_BENEFICIARIO_BOLSA', 'DT_NASCIMENTO_BENEFICIARIO',
#        'BENEFICIARIO_DEFICIENTE_FISICO', 'REGIAO_BENEFICIARIO_BOLSA',
#        'SIGLA_UF_BENEFICIARIO_BOLSA'],
#       dtype='object')

# %%
df.rename(columns = {'ANO_CONCESSAO_BOLSA':'ANO_CONCESSAO', 
                     'CODIGO_EMEC_IES_BOLSA':'CODIGO_IES', 
                     'NOME_IES_BOLSA':'NOME_IES', 
                     'MODALIDADE_ENSINO_BOLSA':'MODALIDADE_ENSINO', 
                     'NOME_CURSO_BOLSA':'NOME_CURSO'}, inplace = True)

# %%
df.rename(columns = {'NOME_TURNO_CURSO_BOLSA':'TURNO_CURSO', 
                     'SEXO_BENEFICIARIO_BOLSA':'SEXO_BENEFICIARIO', 
                     'RACA_BENEFICIARIO_BOLSA':'RACA_BENEFICIARIO', 
                     'REGIAO_BENEFICIARIO_BOLSA':'REGIAO_BENEFICIARIO', 
                     'SIGLA_UF_BENEFICIARIO_BOLSA':'UF_BENEFICIARIO', 
                     'DT_NASCIMENTO_BENEFICIARIO':'ANO_NASCIMENTO_BENEFICIARIO'}, inplace = True)

# %%
df.sample(10)
# Out:
#         ANO_CONCESSAO  CODIGO_IES                            NOME_IES  \
# 52360            2016         203        UNIVERSIDADE SÃO JUDAS TADEU
# 89622            2016         449     UNIVERSIDADE LUTERANA DO BRASIL
# 202036           2016        2723           FACULDADE CATÓLICA RECIFE
# 199157           2016        2581              FACULDADE SÃO SALVADOR
# 38759            2016        1772                  FACULDADE NORDESTE
# 202972           2016        3363                    FACULDADE GUARAÍ
# 28576            2016        1491  CENTRO UNIVERSITÁRIO INTERNACIONAL
# 107038           2016        1491  CENTRO UNIVERSITÁRIO INTERNACIONAL
# 49265            2016         203        UNIVERSIDADE SÃO JUDAS TADEU
# 67980            2016         517      FACULDADE DE EDUCAÇÃO SÃO LUÍS
#
#                TIPO_BOLSA     MODALIDADE_ENSINO                  NOME_CURSO  \
# 52360   BOLSA PARCIAL 50%            PRESENCIAL                Fisioterapia
# 89622      BOLSA INTEGRAL            PRESENCIAL               Administração
# 202036     BOLSA INTEGRAL            PRESENCIAL               Administração
# 199157  BOLSA PARCIAL 50%            PRESENCIAL                     Direito
# 38759   BOLSA PARCIAL 50%            PRESENCIAL                   Logística
# 202972     BOLSA INTEGRAL            PRESENCIAL                Fisioterapia
# 28576   BOLSA PARCIAL 50%  EDUCAÇÃO A DISTÂNCIA          Ciências Contábeis
# 107038  BOLSA PARCIAL 50%  EDUCAÇÃO A DISTÂNCIA  Gestão De Recursos Humanos
# 49265   BOLSA PARCIAL 50%            PRESENCIAL            Engenharia Civil
# 67980      BOLSA INTEGRAL            PRESENCIAL                   Pedagogia
#
#               TURNO_CURSO SEXO_BENEFICIARIO RACA_BENEFICIARIO  \
# 52360             Noturno          Feminino             Parda
# 89622             Noturno         Masculino            Branca
# 202036            Noturno         Masculino             Parda
# 199157           Matutino         Masculino             Parda
# 38759             Noturno         Masculino             Parda
# 202972            Noturno         Masculino             Parda
# 28576   Curso a distância          Feminino            Branca
# 107038  Curso a distância          Feminino            Branca
# 49265             Noturno         Masculino             Parda
# 67980             Noturno          Feminino             Parda
#
#        ANO_NASCIMENTO_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  \
# 52360                   25-10-1995                            NÃO
# 89622                   27-08-1997                            NÃO
# 202036                  20-06-1990                            NÃO
# 199157                  19-09-1997                            NÃO
# 38759                   15-04-1993                            NÃO
# 202972                  21-04-1996                            NÃO
# 28576                   06-06-1989                            NÃO
# 107038                  12-01-1996                            NÃO
# 49265                   21-01-1997                            NÃO
# 67980                   08-07-1994                            NÃO
#
#        REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 52360              SUDESTE              SP
# 89622                  SUL              RS
# 202036            NORDESTE              PE
# 199157            NORDESTE              BA
# 38759             NORDESTE              CE
# 202972               NORTE              TO
# 28576                  SUL              PR
# 107038                 SUL              PR
# 49265              SUDESTE              SP
# 67980              SUDESTE              SP

# %% [markdown]
# ### Descobrindo a idade aproximada* dos beneficiários
#
# é aproximada, pois o dataframe não menciona qual semestre do ano o beneficiário foi contemplado com a bolsa.

# %% [markdown]
# -> Criar uma nova coluna IDADE_APROX_BENEFICIARIO para calcular a idade aproximada deles
#
# -> Alterar o formato da coluna DT_NASCIMENTO_BENEFICIARIO Para Y
#
# -> Calcular com base na coluna ANO_CONCESSAO a idade aproximada do beneficiário

# %%
df['ANO_NASCIMENTO_BENEFICIARIO'] = pd.to_datetime(df['ANO_NASCIMENTO_BENEFICIARIO']).dt.year
print(df['ANO_NASCIMENTO_BENEFICIARIO'])
# Out:
# 0         1995
# 1         1990
# 2         1999
# 3         1997
# 4         1994
#           ...
# 239257    1982
# 239258    1985
# 239259    1997
# 239260    1997
# 239261    1997
# Name: ANO_NASCIMENTO_BENEFICIARIO, Length: 239262, dtype: int64

# %%
df.insert(loc=10, column='IDADE_APROX_BENEFICIARIO', value=10)

# %%
df['IDADE_APROX_BENEFICIARIO'] = df['ANO_CONCESSAO'] - df['ANO_NASCIMENTO_BENEFICIARIO']
df.sample(5)
# Out:
#         ANO_CONCESSAO  CODIGO_IES  \
# 211368           2016         449
# 82436            2016        1173
# 83904            2016        3294
# 123256           2016        1386
# 154560           2016        1270
#
#                                               NOME_IES         TIPO_BOLSA  \
# 211368                 UNIVERSIDADE LUTERANA DO BRASIL     BOLSA INTEGRAL
# 82436                 FACULDADE ANHANGUERA DE BRASÍLIA     BOLSA INTEGRAL
# 83904               FACULDADE DE TECNOLOGIA ENIAC-FAPI     BOLSA INTEGRAL
# 123256                        FACULDADE ESAMC CAMPINAS  BOLSA PARCIAL 50%
# 154560  CENTRO UNIVERSITÁRIO ESTÁCIO DE RIBEIRÃO PRETO     BOLSA INTEGRAL
#
#            MODALIDADE_ENSINO                  NOME_CURSO        TURNO_CURSO  \
# 211368            PRESENCIAL                     Direito            Noturno
# 82436             PRESENCIAL                  Jornalismo            Noturno
# 83904             PRESENCIAL     Construção De Edifícios            Noturno
# 123256            PRESENCIAL     Relações Internacionais           Matutino
# 154560  EDUCAÇÃO A DISTÂNCIA  Gestão De Recursos Humanos  Curso a distância
#
#        SEXO_BENEFICIARIO RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  \
# 211368          Feminino            Branca                         1997
# 82436           Feminino            Branca                         1996
# 83904          Masculino            Branca                         1984
# 123256          Feminino            Branca                         1997
# 154560         Masculino             Parda                         1997
#
#         IDADE_APROX_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  \
# 211368                        19                            NÃO
# 82436                         20                            NÃO
# 83904                         32                            NÃO
# 123256                        19                            NÃO
# 154560                        19                            NÃO
#
#        REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 211368                 SUL              RS
# 82436         CENTRO-OESTE              DF
# 83904              SUDESTE              SP
# 123256             SUDESTE              SP
# 154560             SUDESTE              SP

# %% [markdown]
# ###  Criando intervalos em que se agrupam pessoas de idade aproximada

# %% [markdown]
# -> Criar uma nova coluna FAIXA_ETA_BENEFICIARIO
#
# -> Popular a coluna seguindo os seguintes critérios:
#
#     Menos de 18 anos
#     De 18 a 24 anos
#     De 24 a 30 anos
#     De 30 a 36 anos
#     De 36 a 48 anos
#     De 48 a 60 anos
#     Mais de 60 anos

# %%
df.insert(loc=11, column='FAIXA_ETA_BENEFICIARIO', value='Idade')

# %%
df.head()
# Out:
#    ANO_CONCESSAO  CODIGO_IES  \
# 0           2016          20
# 1           2016          20
# 2           2016          20
# 3           2016          20
# 4           2016         423
#
#                                             NOME_IES         TIPO_BOLSA  \
# 0                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 1                        UNIVERSIDADE DE PASSO FUNDO     BOLSA INTEGRAL
# 2                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 3                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 4  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
#
#   MODALIDADE_ENSINO          NOME_CURSO TURNO_CURSO SEXO_BENEFICIARIO  \
# 0        PRESENCIAL       Administração     Noturno          Feminino
# 1        PRESENCIAL       Administração     Noturno          Feminino
# 2        PRESENCIAL       Administração     Noturno         Masculino
# 3        PRESENCIAL       Administração     Noturno          Feminino
# 4        PRESENCIAL  Ciências Contábeis     Noturno         Masculino
#
#   RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  IDADE_APROX_BENEFICIARIO  \
# 0            Branca                         1995                        21
# 1            Branca                         1990                        26
# 2            Branca                         1999                        17
# 3            Branca                         1997                        19
# 4            Branca                         1994                        22
#
#   FAIXA_ETA_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO  \
# 0                  Idade                            NÃO                 SUL
# 1                  Idade                            NÃO                 SUL
# 2                  Idade                            NÃO                 SUL
# 3                  Idade                            NÃO                 SUL
# 4                  Idade                            NÃO                 SUL
#
#   UF_BENEFICIARIO
# 0              RS
# 1              RS
# 2              RS
# 3              RS
# 4              RS

# %%
for i in range(len (df)): 
    if (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] > 0) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 18):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'Menos de 18 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 18) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 24):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 18 a 24 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 24) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 30):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 24 a 30 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 30) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 36):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 30 a 36 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 36) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 48):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 36 a 48 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 48) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 60):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 48 a 60 anos'
    
    else:
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'Mais de 60 anos'

# %%
df.sample()
# Out:
#         ANO_CONCESSAO  CODIGO_IES                 NOME_IES         TIPO_BOLSA  \
# 203200           2016        3285  FACULDADE SANTO ANTONIO  BOLSA PARCIAL 50%
#
#        MODALIDADE_ENSINO  NOME_CURSO TURNO_CURSO SEXO_BENEFICIARIO  \
# 203200        PRESENCIAL  Enfermagem     Noturno          Feminino
#
#        RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  \
# 203200             Parda                         1996
#
#         IDADE_APROX_BENEFICIARIO FAIXA_ETA_BENEFICIARIO  \
# 203200                        20        De 18 a 24 anos
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 203200                            NÃO            NORDESTE              SE

# %% [markdown]
# # Analisando os dados

# %% [markdown]
# ### Tipo de bolsas

# %%
df['TIPO_BOLSA'].value_counts()
# Out:
# BOLSA INTEGRAL       157406
# BOLSA PARCIAL 50%     81856
# Name: TIPO_BOLSA, dtype: int64

# %% [markdown]
# ### Modalidade de ensino

# %%
df['MODALIDADE_ENSINO'].value_counts()
# Out:
# PRESENCIAL              191397
# EDUCAÇÃO A DISTÂNCIA     47865
# Name: MODALIDADE_ENSINO, dtype: int64

# %% [markdown]
# ### Top 10 - Cursos

# %%
df['NOME_CURSO'].value_counts().head(10)
# Out:
# Administração                 24567
# Direito                       18731
# Pedagogia                     16416
# Ciências Contábeis            12994
# Engenharia Civil              10658
# Educação Física               10100
# Enfermagem                     9212
# Gestão De Recursos Humanos     7259
# Psicologia                     6690
# Engenharia De Produção         6169
# Name: NOME_CURSO, dtype: int64

# %% [markdown]
# ### Turno predominante

# %%
df['TURNO_CURSO'].value_counts().head(6)
# Out:
# Noturno              128714
# Matutino              49368
# Curso a distância     47865
# Integral               6741
# Vespertino             6574
# Name: TURNO_CURSO, dtype: int64

# %% [markdown]
# ### Sexo dos beneficiários

# %%
df['SEXO_BENEFICIARIO'].value_counts()
# Out:
# Feminino     131205
# Masculino    108057
# Name: SEXO_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Raça dos beneficiários

# %%
df['RACA_BENEFICIARIO'].value_counts().head(6)
# Out:
# Parda            107354
# Branca            97298
# Preta             30003
# Amarela            4403
# Indígena            194
# Não Informada        10
# Name: RACA_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Faixa etária dos beneficiários

# %%
df['FAIXA_ETA_BENEFICIARIO'].value_counts()
# Out:
# De 18 a 24 anos     152184
# De 24 a 30 anos      45865
# De 30 a 36 anos      21129
# De 36 a 48 anos      14578
# Menos de 18 anos      2795
# De 48 a 60 anos       2568
# Mais de 60 anos        143
# Name: FAIXA_ETA_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Beneficiários deficientes físicos

# %%
df['BENEFICIARIO_DEFICIENTE_FISICO'].value_counts()
# Out:
# NÃO    237492
# SIM      1770
# Name: BENEFICIARIO_DEFICIENTE_FISICO, dtype: int64

# %% [markdown]
# ### Região x Bolsas

# %%
df['REGIAO_BENEFICIARIO'].value_counts()
# Out:
# SUDESTE         106928
# NORDESTE         49168
# SUL              43427
# CENTRO-OESTE     22057
# NORTE            17682
# Name: REGIAO_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Top 5 - Uf's x Bolsas

# %%
df['UF_BENEFICIARIO'].value_counts().head()
# Out:
# SP    64982
# MG    25198
# RS    16025
# PR    15962
# BA    12511
# Name: UF_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Top 10 - IE's x Bolsas

# %%
df['NOME_IES'].value_counts().head(10)
# Out:
# UNIVERSIDADE PAULISTA                               12679
# UNIVERSIDADE PITÁGORAS UNOPAR                        8199
# CENTRO UNIVERSITÁRIO INTERNACIONAL                   7718
# UNIVERSIDADE SÃO JUDAS TADEU                         5416
# UNIVERSIDADE ESTÁCIO DE SÁ                           5366
# UNIVERSIDADE NOVE DE JULHO                           4217
# UNIVERSIDADE LUTERANA DO BRASIL                      4130
# UNIVERSIDADE DO CEUMA - UNICEUMA                     4108
# UNIVERSIDADE DO OESTE PAULISTA                       4013
# PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS     3906
# Name: NOME_IES, dtype: int64

# %% [markdown]
# ## Criando um novo arquivo csv

# %%
novo_df = df

# %%
novo_df.to_csv('N_Datasets/Novo_Prouni2016.csv', sep=';', encoding='ISO-8859-1', index = False)
