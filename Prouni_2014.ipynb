# %% [markdown]
# # Análise de Dados - Prouni 2014
#
# Conjunto de dados que apresenta as bolsas concedidas e o perfil dos beneficiários do ProUni de 2014.
#
# Os dados são disponibilizados pelo Site Dados Abertos (http://dadosabertos.mec.gov.br/prouni), em arquivo CSV.

# %%
import pandas as pd

df = pd.read_csv ('datasets/pda-prouni-2014.csv', sep=';', encoding = 'ISO-8859-1')

# %% [markdown]
# ## Conhecendo o dataframe

# %%
df.sample(5)
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 219174                 2014                   1139
# 192113                 2014                   1996
# 84224                  2014                   2497
# 41992                  2014                   1185
# 147946                 2014                    449
#
#                                            NOME_IES_BOLSA         TIPO_BOLSA  \
# 219174  FACULDADE DE ESTUDOS ADMINISTRATIVOS DE MINAS ...  BOLSA PARCIAL 50%
# 192113               INSTITUTO CUIABÁ DE ENSINO E CULTURA     BOLSA INTEGRAL
# 84224                                    FACULDADE ATENEU     BOLSA INTEGRAL
# 41992                    CENTRO UNIVERSITÁRIO JORGE AMADO     BOLSA INTEGRAL
# 147946                    UNIVERSIDADE LUTERANA DO BRASIL     BOLSA INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA       NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 219174              PRESENCIAL                Direito               Matutino
# 192113              PRESENCIAL                Direito                Noturno
# 84224               PRESENCIAL           Secretariado                Noturno
# 41992               PRESENCIAL  Redes De Computadores                Noturno
# 147946    EDUCAÇÃO A DISTÂNCIA          Administração      Curso a distância
#
#        CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA RACA_BENEFICIARIO_BOLSA  \
# 219174            ***858326**               Masculino                   Parda
# 192113            ***875151**               Masculino                   Preta
# 84224             ***585813**                Feminino                   Preta
# 41992             ***610555**               Masculino                   Parda
# 147946            ***254310**               Masculino                   Preta
#
#        DT_NASCIMENTO_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  \
# 219174                 07-10-1994                            NÃO
# 192113                 05-12-1989                            NÃO
# 84224                  14-03-1996                            NÃO
# 41992                  02-01-1985                            NÃO
# 147946                 17-04-1971                            NÃO
#
#        REGIAO_BENEFICIARIO_BOLSA SIGLA_UF_BENEFICIARIO_BOLSA  \
# 219174                   SUDESTE                          MG
# 192113              CENTRO-OESTE                          MT
# 84224                   NORDESTE                          CE
# 41992                   NORDESTE                          BA
# 147946                       SUL                          RS
#
#        MUNICIPIO_BENEFICIARIO_BOLSA
# 219174                       ARINOS
# 192113        CHAPADA DOS GUIMARÃES
# 84224                     FORTALEZA
# 41992                      SALVADOR
# 147946                    ENCANTADO

# %%
df.shape
# Out:
# (223598, 15)

# %%
df.dtypes
# Out:
# ANO_CONCESSAO_BOLSA                int64
# CODIGO_EMEC_IES_BOLSA              int64
# NOME_IES_BOLSA                    object
# TIPO_BOLSA                        object
# MODALIDADE_ENSINO_BOLSA           object
# NOME_CURSO_BOLSA                  object
# NOME_TURNO_CURSO_BOLSA            object
# CPF_BENEFICIARIO_BOLSA            object
# SEXO_BENEFICIARIO_BOLSA           object
# RACA_BENEFICIARIO_BOLSA           object
# DT_NASCIMENTO_BENEFICIARIO        object
# BENEFICIARIO_DEFICIENTE_FISICO    object
# REGIAO_BENEFICIARIO_BOLSA         object
# SIGLA_UF_BENEFICIARIO_BOLSA       object
# MUNICIPIO_BENEFICIARIO_BOLSA      object
# dtype: object

# %%
df.isnull().sum()
# Out:
# ANO_CONCESSAO_BOLSA                 0
# CODIGO_EMEC_IES_BOLSA               0
# NOME_IES_BOLSA                      0
# TIPO_BOLSA                          0
# MODALIDADE_ENSINO_BOLSA             0
# NOME_CURSO_BOLSA                  126
# NOME_TURNO_CURSO_BOLSA              0
# CPF_BENEFICIARIO_BOLSA              0
# SEXO_BENEFICIARIO_BOLSA             0
# RACA_BENEFICIARIO_BOLSA             0
# DT_NASCIMENTO_BENEFICIARIO          0
# BENEFICIARIO_DEFICIENTE_FISICO      0
# REGIAO_BENEFICIARIO_BOLSA          21
# SIGLA_UF_BENEFICIARIO_BOLSA        21
# MUNICIPIO_BENEFICIARIO_BOLSA       21
# dtype: int64

# %% [markdown]
# #  Dados nulos
#
# - A Coluna NOME_CURSO_BOLSA, consta a falta de 126 registros;
#
#
# - As Colunas REGIAO_BENEFICIARIO_BOLSA , SIGLA_UF_BENEFICIARIO_BOLSA e MUNICIPIO_BENEFICIARIO_BOLSA, constam falta de 21 registros.

# %% [markdown]
# ###  Atribuindo valores na Coluna NOME_CURSO_BOLSA
#
# -> Todos os elementos vazios serão preenchidos com o valor definido 'Não Registrado'

# %%
df.loc[(df['NOME_CURSO_BOLSA']).isnull()]
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 304                    2014                    423
# 3377                   2014                    437
# 7266                   2014                     82
# 8623                   2014                    780
# 9087                   2014                    338
# ...                     ...                    ...
# 218828                 2014                   2271
# 218829                 2014                   2271
# 218830                 2014                   2271
# 219291                 2014                   2271
# 219292                 2014                   2271
#
#                                            NOME_IES_BOLSA      TIPO_BOLSA  \
# 304     UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA INTEGRAL
# 3377                              UNIVERSIDADE PARANAENSE  BOLSA INTEGRAL
# 7266              UNIVERSIDADE DO OESTE DE SANTA CATARINA  BOLSA INTEGRAL
# 8623                               UNIVERSIDADE DE CUIABÁ  BOLSA INTEGRAL
# 9087     PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS  BOLSA INTEGRAL
# ...                                                   ...             ...
# 218828                    FACULDADE PITÁGORAS DE IPATINGA  BOLSA INTEGRAL
# 218829                    FACULDADE PITÁGORAS DE IPATINGA  BOLSA INTEGRAL
# 218830                    FACULDADE PITÁGORAS DE IPATINGA  BOLSA INTEGRAL
# 219291                    FACULDADE PITÁGORAS DE IPATINGA  BOLSA INTEGRAL
# 219292                    FACULDADE PITÁGORAS DE IPATINGA  BOLSA INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA NOME_CURSO_BOLSA NOME_TURNO_CURSO_BOLSA  \
# 304                 PRESENCIAL              NaN             Vespertino
# 3377                PRESENCIAL              NaN               Integral
# 7266                PRESENCIAL              NaN                Noturno
# 8623                PRESENCIAL              NaN               Matutino
# 9087                PRESENCIAL              NaN                Noturno
# ...                        ...              ...                    ...
# 218828              PRESENCIAL              NaN               Matutino
# 218829              PRESENCIAL              NaN               Matutino
# 218830              PRESENCIAL              NaN               Matutino
# 219291              PRESENCIAL              NaN               Matutino
# 219292              PRESENCIAL              NaN               Matutino
#
#        CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA RACA_BENEFICIARIO_BOLSA  \
# 304               ***589920**               Masculino                  Branca
# 3377              ***239029**                Feminino                  Branca
# 7266              ***703229**               Masculino                  Branca
# 8623              ***942941**                Feminino                   Parda
# 9087              ***160376**                Feminino                  Branca
# ...                       ...                     ...                     ...
# 218828            ***523466**                Feminino                   Parda
# 218829            ***224896**                Feminino                   Parda
# 218830            ***529746**                Feminino                  Branca
# 219291            ***460356**                Feminino                   Parda
# 219292            ***609536**                Feminino                  Branca
#
#        DT_NASCIMENTO_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO  \
# 304                    18-01-1994                            NÃO
# 3377                   09-05-1993                            NÃO
# 7266                   15-10-1990                            NÃO
# 8623                   16-11-1986                            NÃO
# 9087                   02-09-1994                            NÃO
# ...                           ...                            ...
# 218828                 24-03-1992                            NÃO
# 218829                 24-06-1996                            NÃO
# 218830                 02-09-1988                            NÃO
# 219291                 06-07-1990                            NÃO
# 219292                 25-11-1995                            NÃO
#
#        REGIAO_BENEFICIARIO_BOLSA SIGLA_UF_BENEFICIARIO_BOLSA  \
# 304                          SUL                          RS
# 3377                         SUL                          PR
# 7266                         SUL                          SC
# 8623                CENTRO-OESTE                          MT
# 9087                     SUDESTE                          MG
# ...                          ...                         ...
# 218828                   SUDESTE                          MG
# 218829                   SUDESTE                          MG
# 218830                   SUDESTE                          MG
# 219291                   SUDESTE                          MG
# 219292                   SUDESTE                          MG
#
#        MUNICIPIO_BENEFICIARIO_BOLSA
# 304                    SANTO ÂNGELO
# 3377                       CASCAVEL
# 7266            SÃO MIGUEL DO OESTE
# 8623                         CUIABÁ
# 9087                       CONTAGEM
# ...                             ...
# 218828           SANTANA DO PARAÍSO
# 218829           CORONEL FABRICIANO
# 218830                 CÓRREGO NOVO
# 219291                      TIMÓTEO
# 219292                      TIMÓTEO
#
# [126 rows x 15 columns]

# %%
df.update(df['NOME_CURSO_BOLSA'].fillna('Não Registrado'))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223598 entries, 0 to 223597
# Data columns (total 15 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   ANO_CONCESSAO_BOLSA             223598 non-null  int64
#  1   CODIGO_EMEC_IES_BOLSA           223598 non-null  int64
#  2   NOME_IES_BOLSA                  223598 non-null  object
#  3   TIPO_BOLSA                      223598 non-null  object
#  4   MODALIDADE_ENSINO_BOLSA         223598 non-null  object
#  5   NOME_CURSO_BOLSA                223598 non-null  object
#  6   NOME_TURNO_CURSO_BOLSA          223598 non-null  object
#  7   CPF_BENEFICIARIO_BOLSA          223598 non-null  object
#  8   SEXO_BENEFICIARIO_BOLSA         223598 non-null  object
#  9   RACA_BENEFICIARIO_BOLSA         223598 non-null  object
#  10  DT_NASCIMENTO_BENEFICIARIO      223598 non-null  object
#  11  BENEFICIARIO_DEFICIENTE_FISICO  223598 non-null  object
#  12  REGIAO_BENEFICIARIO_BOLSA       223577 non-null  object
#  13  SIGLA_UF_BENEFICIARIO_BOLSA     223577 non-null  object
#  14  MUNICIPIO_BENEFICIARIO_BOLSA    223577 non-null  object
# dtypes: int64(2), object(13)
# memory usage: 25.6+ MB

# %% [markdown]
# ### Analisando as Colunas:
#
# #### REGIAO_BENEFICIARIO_BOLSA, SIGLA_UF_BENEFICIARIO_BOLSA e MUNICIPIO_BENEFICIARIO_BOLSA

# %% [markdown]
# - 1º: será atribuído o valor 'Não Registrado' nas linhas de cada coluna;
#
#
# - 2º: Após a análise do df e com o intuito de minimizar esses registros, vê-se a possibilidade de substituição dos valores nas colunas: REGIAO_BENEFICIARIO_BOLSA e SIGLA_UF_BENEFICIARIO_BOLSA
#
# -> essa substituição terá como base os Códigos das IE's ou os Nomes das IE's
#
# -> a substituição ocorrerá somente para as IE's mais frequentes no dataframe

# %%
df['REGIAO_BENEFICIARIO_BOLSA'].fillna('Não Registrada', inplace = True)
df['SIGLA_UF_BENEFICIARIO_BOLSA'].fillna('Não Registrada', inplace = True)
df['MUNICIPIO_BENEFICIARIO_BOLSA'].fillna('Não Registrado', inplace = True)

# %%
df.loc[(df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada')].head(21)
# Out:
#         ANO_CONCESSAO_BOLSA  CODIGO_EMEC_IES_BOLSA  \
# 47204                  2014                   1493
# 48154                  2014                   4086
# 76186                  2014                   1806
# 79058                  2014                   2150
# 80960                  2014                   2773
# 85187                  2014                   2773
# 86602                  2014                   4452
# 86720                  2014                   4452
# 93954                  2014                     15
# 104318                 2014                  13783
# 105433                 2014                   1821
# 106231                 2014                   1821
# 106232                 2014                   1821
# 107046                 2014                   1821
# 107047                 2014                   1821
# 107048                 2014                   1821
# 107049                 2014                   1821
# 107050                 2014                   1821
# 109528                 2014                   4865
# 112286                 2014                   4865
# 119823                 2014                   1472
#
#                                 NOME_IES_BOLSA         TIPO_BOLSA  \
# 47204                    FACULDADE ALVES FARIA     BOLSA INTEGRAL
# 48154           FACULDADE DE TECNOLOGIA JARDIM  BOLSA PARCIAL 50%
# 76186                    FACULDADE FERNÃO DIAS     BOLSA INTEGRAL
# 79058                       FACULDADE DO PIAUÍ     BOLSA INTEGRAL
# 80960                      FACULDADE DE MACAPÁ     BOLSA INTEGRAL
# 85187                      FACULDADE DE MACAPÁ     BOLSA INTEGRAL
# 86602        FACULDADE METROPOLITANA DE MARABÁ  BOLSA PARCIAL 50%
# 86720        FACULDADE METROPOLITANA DE MARABÁ     BOLSA INTEGRAL
# 93954      UNIVERSIDADE CATÓLICA DE PETRÓPOLIS     BOLSA INTEGRAL
# 104318      FACULDADES UNIDAS FEIRA DE SANTANA  BOLSA PARCIAL 50%
# 105433                         FACULDADE LIONS     BOLSA INTEGRAL
# 106231                         FACULDADE LIONS     BOLSA INTEGRAL
# 106232                         FACULDADE LIONS     BOLSA INTEGRAL
# 107046                         FACULDADE LIONS     BOLSA INTEGRAL
# 107047                         FACULDADE LIONS     BOLSA INTEGRAL
# 107048                         FACULDADE LIONS     BOLSA INTEGRAL
# 107049                         FACULDADE LIONS     BOLSA INTEGRAL
# 107050                         FACULDADE LIONS     BOLSA INTEGRAL
# 109528         FACULDADE PITÁGORAS DE SÃO LUIZ     BOLSA INTEGRAL
# 112286         FACULDADE PITÁGORAS DE SÃO LUIZ     BOLSA INTEGRAL
# 119823  CENTRO UNIVERSITÁRIO LEONARDO DA VINCI     BOLSA INTEGRAL
#
#        MODALIDADE_ENSINO_BOLSA                               NOME_CURSO_BOLSA  \
# 47204               PRESENCIAL                                  Administração
# 48154               PRESENCIAL                                 Gestão Pública
# 76186               PRESENCIAL                             Ciências Contábeis
# 79058               PRESENCIAL                                        Direito
# 80960               PRESENCIAL                               Gestão Ambiental
# 85187               PRESENCIAL                                     Enfermagem
# 86602               PRESENCIAL                                   Fisioterapia
# 86720               PRESENCIAL                               Engenharia Civil
# 93954               PRESENCIAL                               Engenharia Civil
# 104318              PRESENCIAL                                    Biomedicina
# 105433              PRESENCIAL                                        Direito
# 106231              PRESENCIAL  Comunicação Social - Publicidade E Propaganda
# 106232              PRESENCIAL  Comunicação Social - Publicidade E Propaganda
# 107046              PRESENCIAL                                        Direito
# 107047              PRESENCIAL                                        Direito
# 107048              PRESENCIAL                                        Direito
# 107049              PRESENCIAL                                        Direito
# 107050              PRESENCIAL                                        Direito
# 109528              PRESENCIAL                          Ciência Da Computação
# 112286              PRESENCIAL                          Ciência Da Computação
# 119823    EDUCAÇÃO A DISTÂNCIA                             Letras - Português
#
#        NOME_TURNO_CURSO_BOLSA CPF_BENEFICIARIO_BOLSA SEXO_BENEFICIARIO_BOLSA  \
# 47204                Matutino            ***275601**               Masculino
# 48154                 Noturno            ***758608**                Feminino
# 76186                 Noturno            ***519768**                Feminino
# 79058                 Noturno            ***741443**                Feminino
# 80960                 Noturno            ***398082**                Feminino
# 85187                Matutino            ***543742**                Feminino
# 86602                 Noturno            ***710382**                Feminino
# 86720              Vespertino            ***126932**                Feminino
# 93954                 Noturno            ***748317**                Feminino
# 104318               Matutino            ***754165**                Feminino
# 105433                Noturno            ***273534**               Masculino
# 106231                Noturno            ***798441**                Feminino
# 106232                Noturno            ***897643**               Masculino
# 107046               Matutino            ***702161**               Masculino
# 107047               Matutino            ***826121**                Feminino
# 107048               Matutino            ***393422**               Masculino
# 107049               Matutino            ***232272**                Feminino
# 107050               Matutino            ***494411**                Feminino
# 109528               Matutino            ***253103**                Feminino
# 112286               Matutino            ***326933**               Masculino
# 119823      Curso a distância            ***660489**               Masculino
#
#        RACA_BENEFICIARIO_BOLSA DT_NASCIMENTO_BENEFICIARIO  \
# 47204                   Branca                 21-09-1995
# 48154                    Preta                 04-08-1993
# 76186                    Preta                 26-05-1995
# 79058                   Branca                 08-07-1996
# 80960                    Parda                 23-04-1993
# 85187                    Parda                 01-09-1994
# 86602                    Preta                 29-01-1996
# 86720                    Parda                 06-09-1991
# 93954                   Branca                 24-02-1996
# 104318                   Parda                 15-06-1996
# 105433                   Preta                 06-11-1994
# 106231                   Parda                 01-01-1990
# 106232                   Parda                 02-09-1995
# 107046                   Parda                 10-05-1989
# 107047                  Branca                 21-12-1984
# 107048                   Parda                 20-02-1993
# 107049                   Parda                 06-08-1996
# 107050                   Parda                 09-09-1994
# 109528                   Preta                 22-05-1995
# 112286                   Parda                 17-05-1991
# 119823                  Branca                 16-02-1966
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO_BOLSA  \
# 47204                             NÃO            Não Registrada
# 48154                             NÃO            Não Registrada
# 76186                             NÃO            Não Registrada
# 79058                             NÃO            Não Registrada
# 80960                             NÃO            Não Registrada
# 85187                             NÃO            Não Registrada
# 86602                             NÃO            Não Registrada
# 86720                             NÃO            Não Registrada
# 93954                             NÃO            Não Registrada
# 104318                            NÃO            Não Registrada
# 105433                            NÃO            Não Registrada
# 106231                            NÃO            Não Registrada
# 106232                            NÃO            Não Registrada
# 107046                            NÃO            Não Registrada
# 107047                            NÃO            Não Registrada
# 107048                            NÃO            Não Registrada
# 107049                            NÃO            Não Registrada
# 107050                            NÃO            Não Registrada
# 109528                            NÃO            Não Registrada
# 112286                            NÃO            Não Registrada
# 119823                            NÃO            Não Registrada
#
#        SIGLA_UF_BENEFICIARIO_BOLSA MUNICIPIO_BENEFICIARIO_BOLSA
# 47204               Não Registrada               Não Registrado
# 48154               Não Registrada               Não Registrado
# 76186               Não Registrada               Não Registrado
# 79058               Não Registrada               Não Registrado
# 80960               Não Registrada               Não Registrado
# 85187               Não Registrada               Não Registrado
# 86602               Não Registrada               Não Registrado
# 86720               Não Registrada               Não Registrado
# 93954               Não Registrada               Não Registrado
# 104318              Não Registrada               Não Registrado
# 105433              Não Registrada               Não Registrado
# 106231              Não Registrada               Não Registrado
# 106232              Não Registrada               Não Registrado
# 107046              Não Registrada               Não Registrado
# 107047              Não Registrada               Não Registrado
# 107048              Não Registrada               Não Registrado
# 107049              Não Registrada               Não Registrado
# 107050              Não Registrada               Não Registrado
# 109528              Não Registrada               Não Registrado
# 112286              Não Registrada               Não Registrado
# 119823              Não Registrada               Não Registrado

# %%
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE LIONS')].count()
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE DE MACAPÁ')].count()
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE METROPOLITANA DE MARABÁ')].count()

# %%
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE LIONS') & (df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada')].count()

# %%
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE LIONS')].head(23)
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE DE MACAPÁ') & (df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada')].head(2)
#df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE METROPOLITANA DE MARABÁ')].sample(10)

# %% [markdown]
# ### Substituição dos valores nas colunas REGIAO_BENEFICIARIO_BOLSA e SIGLA_UF_BENEFICIARIO_BOLSA

# %%
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE LIONS') & (df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'REGIAO_BENEFICIARIO_BOLSA'] = 'CENTRO-OESTE'
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE DE MACAPÁ') & (df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'REGIAO_BENEFICIARIO_BOLSA'] = 'NORTE'
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE METROPOLITANA DE MARABÁ') & (df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'REGIAO_BENEFICIARIO_BOLSA'] = 'NORTE'

# %%
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE LIONS') & (df['SIGLA_UF_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'SIGLA_UF_BENEFICIARIO_BOLSA'] = 'GO'
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE DE MACAPÁ') & (df['SIGLA_UF_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'SIGLA_UF_BENEFICIARIO_BOLSA'] = 'AP'
df.loc[(df['NOME_IES_BOLSA'] == 'FACULDADE METROPOLITANA DE MARABÁ') & (df['SIGLA_UF_BENEFICIARIO_BOLSA'] == 'Não Registrada'), 'SIGLA_UF_BENEFICIARIO_BOLSA'] = 'PA'

# %%
df.loc[(df['REGIAO_BENEFICIARIO_BOLSA'] == 'Não Registrada')].count()
# Out:
# ANO_CONCESSAO_BOLSA               9
# CODIGO_EMEC_IES_BOLSA             9
# NOME_IES_BOLSA                    9
# TIPO_BOLSA                        9
# MODALIDADE_ENSINO_BOLSA           9
# NOME_CURSO_BOLSA                  9
# NOME_TURNO_CURSO_BOLSA            9
# CPF_BENEFICIARIO_BOLSA            9
# SEXO_BENEFICIARIO_BOLSA           9
# RACA_BENEFICIARIO_BOLSA           9
# DT_NASCIMENTO_BENEFICIARIO        9
# BENEFICIARIO_DEFICIENTE_FISICO    9
# REGIAO_BENEFICIARIO_BOLSA         9
# SIGLA_UF_BENEFICIARIO_BOLSA       9
# MUNICIPIO_BENEFICIARIO_BOLSA      9
# dtype: int64

# %% [markdown]
# ### Excluindo as Colunas CPF_BENEFICIARIO_BOLSA e MUNICIPIO_BENEFICIARIO_BOLSA

# %%
df.drop(['CPF_BENEFICIARIO_BOLSA', 'MUNICIPIO_BENEFICIARIO_BOLSA'], axis = 1, inplace = True)

# %% [markdown]
# ### Renomeando Colunas

# %%
df.columns
# Out:
# Index(['ANO_CONCESSAO_BOLSA', 'CODIGO_EMEC_IES_BOLSA', 'NOME_IES_BOLSA',
#        'TIPO_BOLSA', 'MODALIDADE_ENSINO_BOLSA', 'NOME_CURSO_BOLSA',
#        'NOME_TURNO_CURSO_BOLSA', 'SEXO_BENEFICIARIO_BOLSA',
#        'RACA_BENEFICIARIO_BOLSA', 'DT_NASCIMENTO_BENEFICIARIO',
#        'BENEFICIARIO_DEFICIENTE_FISICO', 'REGIAO_BENEFICIARIO_BOLSA',
#        'SIGLA_UF_BENEFICIARIO_BOLSA'],
#       dtype='object')

# %%
df.rename(columns = {'ANO_CONCESSAO_BOLSA':'ANO_CONCESSAO', 
                     'CODIGO_EMEC_IES_BOLSA':'CODIGO_IES', 
                     'NOME_IES_BOLSA':'NOME_IES', 
                     'MODALIDADE_ENSINO_BOLSA':'MODALIDADE_ENSINO', 
                     'NOME_CURSO_BOLSA':'NOME_CURSO'}, inplace = True)

# %%
df.rename(columns = {'NOME_TURNO_CURSO_BOLSA':'TURNO_CURSO', 
                     'SEXO_BENEFICIARIO_BOLSA':'SEXO_BENEFICIARIO', 
                     'RACA_BENEFICIARIO_BOLSA':'RACA_BENEFICIARIO', 
                     'REGIAO_BENEFICIARIO_BOLSA':'REGIAO_BENEFICIARIO', 
                     'SIGLA_UF_BENEFICIARIO_BOLSA':'UF_BENEFICIARIO', 
                     'DT_NASCIMENTO_BENEFICIARIO':'ANO_NASCIMENTO_BENEFICIARIO'}, inplace = True)

# %% [markdown]
# ### Descobrindo a idade aproximada* dos beneficiários
#
# * é aproximada, pois o dataframe não menciona qual semestre do ano o beneficiário foi contemplado pela bolsa.

# %% [markdown]
# -> Criar uma nova coluna IDADE_APROX_BENEFICIARIO para calcular a idade aproximada deles
#
# -> Alterar o formato da coluna DT_NASCIMENTO_BENEFICIARIO Para Y
#
# -> Calcular com base na coluna ANO_CONCESSAO a idade aproximada do beneficiário

# %%
df['ANO_NASCIMENTO_BENEFICIARIO'] = pd.to_datetime(df['ANO_NASCIMENTO_BENEFICIARIO']).dt.year
print(df['ANO_NASCIMENTO_BENEFICIARIO'])
# Out:
# 0         1978
# 1         1966
# 2         1996
# 3         1993
# 4         1990
#           ...
# 223593    1982
# 223594    1987
# 223595    1993
# 223596    1992
# 223597    1974
# Name: ANO_NASCIMENTO_BENEFICIARIO, Length: 223598, dtype: int64

# %%
df.insert(loc=10, column='IDADE_APROX_BENEFICIARIO', value=10)

# %%
df.head(1)
# Out:
#    ANO_CONCESSAO  CODIGO_IES                     NOME_IES         TIPO_BOLSA  \
# 0           2014          20  UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
#
#   MODALIDADE_ENSINO     NOME_CURSO TURNO_CURSO SEXO_BENEFICIARIO  \
# 0        PRESENCIAL  Administração     Noturno         Masculino
#
#   RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  IDADE_APROX_BENEFICIARIO  \
# 0            Branca                         1978                        10
#
#   BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 0                            NÃO                 SUL              RS

# %%
df['IDADE_APROX_BENEFICIARIO'] = df['ANO_CONCESSAO'] - df['ANO_NASCIMENTO_BENEFICIARIO']
df.sample(5)
# Out:
#         ANO_CONCESSAO  CODIGO_IES  \
# 15763            2014         298
# 189574           2014        2754
# 152304           2014          82
# 117507           2014        1107
# 1597             2014        1032
#
#                                            NOME_IES      TIPO_BOLSA  \
# 15763                 UNIVERSIDADE PITÁGORAS UNOPAR  BOLSA INTEGRAL
# 189574                          FACULDADE SÃO PAULO  BOLSA INTEGRAL
# 152304      UNIVERSIDADE DO OESTE DE SANTA CATARINA  BOLSA INTEGRAL
# 117507        Centro Universitário Estácio do Ceará  BOLSA INTEGRAL
# 1597    CENTRO UNIVERSITÁRIO SALESIANO DE SÃO PAULO  BOLSA INTEGRAL
#
#            MODALIDADE_ENSINO                          NOME_CURSO  \
# 15763   EDUCAÇÃO A DISTÂNCIA                    Gestão Ambiental
# 189574            PRESENCIAL                          Enfermagem
# 152304            PRESENCIAL                           Agronomia
# 117507            PRESENCIAL                  Ciências Contábeis
# 1597              PRESENCIAL  Engenharia De Automação E Controle
#
#               TURNO_CURSO SEXO_BENEFICIARIO RACA_BENEFICIARIO  \
# 15763   Curso a distância          Feminino             Parda
# 189574            Noturno          Feminino             Parda
# 152304            Noturno         Masculino             Parda
# 117507         Vespertino          Feminino             Preta
# 1597              Noturno         Masculino            Branca
#
#         ANO_NASCIMENTO_BENEFICIARIO  IDADE_APROX_BENEFICIARIO  \
# 15763                          1974                        40
# 189574                         1993                        21
# 152304                         1994                        20
# 117507                         1991                        23
# 1597                           1992                        22
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 15763                             NÃO            NORDESTE              BA
# 189574                            NÃO               NORTE              RO
# 152304                            NÃO                 SUL              SC
# 117507                            NÃO            NORDESTE              CE
# 1597                              NÃO             SUDESTE              SP

# %% [markdown]
# ### Criando intervalos em que se agrupam pessoas de idade aproximada

# %% [markdown]
# -> Criar uma nova coluna FAIXA_ETA_BENEFICIARIO
#
# -> Popular a coluna seguindo os seguintes critérios:
#
#     Menos de 18 anos
#     De 18 a 24 anos
#     De 24 a 30 anos
#     De 30 a 36 anos
#     De 36 a 48 anos
#     De 48 a 60 anos
#     Mais de 60 anos

# %%
df.insert(loc=11, column='FAIXA_ETA_BENEFICIARIO', value='Idade')

# %%
df.head()
# Out:
#    ANO_CONCESSAO  CODIGO_IES  \
# 0           2014          20
# 1           2014          20
# 2           2014         423
# 3           2014         423
# 4           2014         423
#
#                                             NOME_IES         TIPO_BOLSA  \
# 0                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 1                        UNIVERSIDADE DE PASSO FUNDO  BOLSA PARCIAL 50%
# 2  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...     BOLSA INTEGRAL
# 3  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...  BOLSA PARCIAL 50%
# 4  UNIVERSIDADE REGIONAL INTEGRADA DO ALTO URUGUA...     BOLSA INTEGRAL
#
#   MODALIDADE_ENSINO           NOME_CURSO TURNO_CURSO SEXO_BENEFICIARIO  \
# 0        PRESENCIAL        Administração     Noturno         Masculino
# 1        PRESENCIAL        Administração     Noturno         Masculino
# 2        PRESENCIAL  Ciências Biológicas     Noturno          Feminino
# 3        PRESENCIAL  Ciências Biológicas     Noturno          Feminino
# 4        PRESENCIAL            Agronomia     Noturno          Feminino
#
#   RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  IDADE_APROX_BENEFICIARIO  \
# 0            Branca                         1978                        36
# 1            Branca                         1966                        48
# 2            Branca                         1996                        18
# 3            Branca                         1993                        21
# 4            Branca                         1990                        24
#
#   FAIXA_ETA_BENEFICIARIO BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO  \
# 0                  Idade                            NÃO                 SUL
# 1                  Idade                            NÃO                 SUL
# 2                  Idade                            NÃO                 SUL
# 3                  Idade                            NÃO                 SUL
# 4                  Idade                            NÃO                 SUL
#
#   UF_BENEFICIARIO
# 0              RS
# 1              RS
# 2              RS
# 3              RS
# 4              RS

# %%
for i in range(len (df)): 
    if (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] > 0) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 18):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'Menos de 18 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 18) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 24):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 18 a 24 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 24) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 30):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 24 a 30 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 30) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 36):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 30 a 36 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 36) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 48):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 36 a 48 anos'
    
    elif (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] >= 48) & (df.loc[i, 'IDADE_APROX_BENEFICIARIO'] < 60):
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'De 48 a 60 anos'
    
    else:
        df.loc[i, 'FAIXA_ETA_BENEFICIARIO'] = 'Mais de 60 anos'

# %%
df.sample()
# Out:
#         ANO_CONCESSAO  CODIGO_IES                          NOME_IES  \
# 190143           2014        1711  FACULDADE DE PRESIDENTE PRUDENTE
#
#             TIPO_BOLSA MODALIDADE_ENSINO          NOME_CURSO TURNO_CURSO  \
# 190143  BOLSA INTEGRAL        PRESENCIAL  Ciências Contábeis     Noturno
#
#        SEXO_BENEFICIARIO RACA_BENEFICIARIO  ANO_NASCIMENTO_BENEFICIARIO  \
# 190143          Feminino             Parda                         1989
#
#         IDADE_APROX_BENEFICIARIO FAIXA_ETA_BENEFICIARIO  \
# 190143                        25        De 24 a 30 anos
#
#        BENEFICIARIO_DEFICIENTE_FISICO REGIAO_BENEFICIARIO UF_BENEFICIARIO
# 190143                            NÃO             SUDESTE              SP

# %% [markdown]
# # Analisando os dados

# %% [markdown]
# ### Tipos de bolsas

# %%
df['TIPO_BOLSA'].value_counts()
# Out:
# BOLSA INTEGRAL       176033
# BOLSA PARCIAL 50%     47565
# Name: TIPO_BOLSA, dtype: int64

# %% [markdown]
# ### Modalidade de ensino

# %%
df['MODALIDADE_ENSINO'].value_counts()
# Out:
# PRESENCIAL              177536
# EDUCAÇÃO A DISTÂNCIA     46062
# Name: MODALIDADE_ENSINO, dtype: int64

# %% [markdown]
# ### Top 10 - Cursos

# %%
df['NOME_CURSO'].value_counts().head(10)
# Out:
# Administração                 27163
# Direito                       18712
# Pedagogia                     16337
# Ciências Contábeis            13638
# Gestão De Recursos Humanos     8807
# Engenharia Civil               8498
# Enfermagem                     7769
# Educação Física                6668
# Serviço Social                 5974
# Psicologia                     5590
# Name: NOME_CURSO, dtype: int64

# %% [markdown]
# ### Turno predominante

# %%
df['TURNO_CURSO'].value_counts()
# Out:
# Noturno              127635
# Curso a distância     46062
# Matutino              38254
# Integral               6247
# Vespertino             5400
# Name: TURNO_CURSO, dtype: int64

# %% [markdown]
# ### Sexo dos beneficiários

# %%
df['SEXO_BENEFICIARIO'].value_counts()
# Out:
# Feminino     126837
# Masculino     96761
# Name: SEXO_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Raça dos beneficiários

# %%
df['RACA_BENEFICIARIO'].value_counts()
# Out:
# Parda            96935
# Branca           93180
# Preta            29291
# Amarela           3841
# Indígena           181
# Não Informada      170
# Name: RACA_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Faixa etária dos Beneficiários

# %%
df['FAIXA_ETA_BENEFICIARIO'].value_counts()
# Out:
# De 18 a 24 anos     131183
# De 24 a 30 anos      45897
# De 30 a 36 anos      23079
# De 36 a 48 anos      17420
# De 48 a 60 anos       3229
# Menos de 18 anos      2580
# Mais de 60 anos        210
# Name: FAIXA_ETA_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Beneficiário deficientes físicos

# %%
df['BENEFICIARIO_DEFICIENTE_FISICO'].value_counts()
# Out:
# NÃO    221825
# SIM      1773
# Name: BENEFICIARIO_DEFICIENTE_FISICO, dtype: int64

# %% [markdown]
# ### Região x Bolsas

# %%
df['REGIAO_BENEFICIARIO'].value_counts()
# Out:
# SUDESTE           106137
# SUL                41579
# NORDESTE           39535
# CENTRO-OESTE       21672
# NORTE              14666
# Não Registrada         9
# Name: REGIAO_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Top 5 -  UF's x Bolsas

# %%
df['UF_BENEFICIARIO'].value_counts().head()
# Out:
# SP    62029
# MG    26827
# RS    19252
# PR    14715
# RJ    13017
# Name: UF_BENEFICIARIO, dtype: int64

# %% [markdown]
# ### Top 10 - IE's x Bolsas

# %%
df['NOME_IES'].value_counts().head(10)
# Out:
# UNIVERSIDADE PITÁGORAS UNOPAR                       17443
# UNIVERSIDADE PAULISTA                               10414
# UNIVERSIDADE ANHANGUERA - UNIDERP                    7634
# UNIVERSIDADE ESTÁCIO DE SÁ                           6706
# UNIVERSIDADE SÃO JUDAS TADEU                         4264
# UNIVERSIDADE LUTERANA DO BRASIL                      4206
# UNIVERSIDADE NOVE DE JULHO                           3394
# PONTIFÍCIA UNIVERSIDADE CATÓLICA DE MINAS GERAIS     3298
# UNIVERSIDADE DO OESTE PAULISTA                       2807
# CENTRO UNIVERSITÁRIO LEONARDO DA VINCI               2717
# Name: NOME_IES, dtype: int64

# %% [markdown]
# ## Criando um novo arquivo csv

# %%
novo_df = df

# %%
novo_df.to_csv('N_Datasets/Novo_Prouni2014.csv', sep=';', encoding = 'ISO-8859-1', index = False)
